# %% [markdown]
# <br/>
# <img src="images/LOGO-CORREO_x.png" alt="SkillNest" width="280px" align="left"/>
# <img src="images/LOGO-CORREO_x.png" alt="SkillNest" width="280px" align="right"/>
# <div align="center">
# <h2>Bootcamp Data Science — Módulo 2</h2><br/>
# <h1>Semana 7 · Viernes — PROYECTO INTEGRADOR: Calidad del Vino</h1>
# <h3>Todo lo de la semana en un solo proyecto</h3>
# <br/>
#     <b>Instructor:</b> Jesús Ortiz · jesus.jeduardo7@gmail.com<br/><br/>
#     <b>SkillNest · b2b-sonda-data-science</b>
# </div>
# <br/>

# %% [markdown]
# ## 🎯 Misión del día
#
# Hoy NO es una clase tradicional — es un **proyecto guiado** que integra TODA la semana:
#
# 1. ✅ Pipeline completo con ColumnTransformer
# 2. ✅ KNN, Decision Tree, Random Forest y Regresión Logística
# 3. ✅ Métricas correctas para clases desbalanceadas
# 4. ✅ Matriz de confusión + curva ROC
# 5. ✅ GridSearchCV para tunear el ganador
# 6. ✅ Análisis de coeficientes y feature importance
# 7. ✅ Guardar el modelo final con joblib
#
# **El problema:** trabajamos para una bodega de vinos. Tenemos 1,599 vinos tintos con sus propiedades químicas y un puntaje de calidad (3–8) dado por catadores. La bodega quiere un sistema automático que **clasifique los vinos como buenos o no buenos** para acelerar el proceso de catación.
#
# **Dataset:**
# ```python
# url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/winequality-red.csv'
# df = pd.read_csv(url)  # ⚠️ NO trae header — recordar el truco!
# ```
#
# **Columnas:** 11 propiedades químicas + `quality` (target original, valores 3–8).
#
# **Transformación del target:** vamos a convertir el problema de **regresión a clasificación binaria**:
# - `quality >= 7` → **bueno** (1)
# - `quality <  7` → **no bueno** (0)

# %% [markdown]
# ## FASE 1 — Carga y exploración

# %% [markdown]
# ### Tareas
#
# 1. Cargar el dataset usando el truco de `names=cols, header=0` (los nombres están abajo).
# 2. Crear la columna binaria `quality_bin` (1 si quality >= 7, 0 si no).
# 3. Eliminar la columna original `quality`.
# 4. **Visualizar la distribución de clases** — ¿está balanceado?
# 5. **Heatmap de correlación** entre las 11 features y el target.
# 6. Identificar las 3 features más correlacionadas con `quality_bin`.
#
# **Nombres de columnas:**
# ```python
# cols = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#         'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide',
#         'density', 'pH', 'sulphates', 'alcohol', 'quality']
# ```

# %%
# FASE 1 — Carga + exploración 👇

# %% [markdown]
# ## FASE 2 — Pipeline + split estratificado
#
# ### Tareas
#
# 7. Definir `X` (las 11 features) y `y = quality_bin`.
# 8. Train/test split 80/20 con `stratify=y` y `random_state=42`.
# 9. Construir un pipeline mínimo con `StandardScaler`. (No hay categóricas en este dataset, todas son numéricas.)

# %%
# FASE 2 — Pipeline + split 👇

# %% [markdown]
# ## FASE 3 — Benchmark de los 4 modelos de la semana
#
# ### Tareas
#
# 10. Entrenar 4 pipelines, todos con StandardScaler + modelo:
#     - `KNeighborsClassifier(n_neighbors=11)`
#     - `DecisionTreeClassifier(max_depth=5, random_state=42)`
#     - `RandomForestClassifier(n_estimators=200, random_state=42, n_jobs=-1)`
#     - `LogisticRegression(max_iter=1000, random_state=42)`
# 11. Para cada uno calcular: **Accuracy, Precision, Recall, F1, AUC** (recuerda que las clases están desbalanceadas).
# 12. Construir una **tabla comparativa**.
# 13. Hacer un **barplot del F1** para visualizar el ranking.
# 14. ¿Qué modelo ganó en F1?

# %%
# FASE 3 — Benchmark de los 4 modelos 👇

# %% [markdown]
# ## FASE 4 — Análisis de errores (matriz + ROC)
#
# ### Tareas
#
# 15. Para los **2 mejores modelos**, mostrar la **matriz de confusión**.
# 16. Graficar las **curvas ROC** de los 4 modelos en el mismo gráfico, con sus AUC.
# 17. ¿Cuántos vinos buenos se le escapan al modelo ganador? (FN) ¿Es aceptable?
# 18. Si la bodega tolera máximo un 10% de error en falsos positivos, ¿qué umbral conviene?

# %%
# FASE 4 — Matrices + curvas ROC 👇

# %% [markdown]
# ## FASE 5 — Tuning del ganador con GridSearchCV
#
# ### Tareas
#
# 19. Tomar el modelo ganador (probablemente RandomForest) y hacer **GridSearchCV con `cv=5`** y `scoring='f1'`.
# 20. Si elegiste RandomForest, prueba:
#     ```python
#     param_grid = {
#         'mod__n_estimators': [200, 500],
#         'mod__max_depth': [5, 10, 20, None],
#         'mod__min_samples_leaf': [1, 3, 5]
#     }
#     ```
# 21. Reportar mejores hiperparámetros + métricas finales en test.
# 22. Comparar el F1 antes y después del tuning.

# %%
# FASE 5 — Tuning con GridSearchCV 👇

# %% [markdown]
# ## FASE 6 — Interpretabilidad: feature importance + coeficientes
#
# ### Tareas
#
# 23. Del modelo tuneado, extraer **feature importance** (si es RF/DT) o **coeficientes** (si es Logística).
# 24. Graficar el ranking.
# 25. **Pregunta para la bodega:** ¿qué 3 propiedades químicas debería cuidar más para hacer un vino bueno?

# %%
# FASE 6 — Interpretabilidad 👇

# %% [markdown]
# ## FASE 7 — Producción: guardar y predecir vinos nuevos
#
# ### Tareas
#
# 26. Guardar el pipeline completo con `joblib.dump('modelo_vino_final.joblib')`.
# 27. Cargarlo de nuevo con `joblib.load()`.
# 28. Predecir la calidad de estos 3 vinos:
#     ```python
#     vinos = pd.DataFrame([
#         # Vino joven barato
#         {'fixed_acidity': 7.4, 'volatile_acidity': 0.7, 'citric_acid': 0.0,
#          'residual_sugar': 1.9, 'chlorides': 0.076, 'free_sulfur_dioxide': 11.0,
#          'total_sulfur_dioxide': 34.0, 'density': 0.9978, 'pH': 3.51,
#          'sulphates': 0.56, 'alcohol': 9.4},
#         # Vino de gama media
#         {'fixed_acidity': 8.5, 'volatile_acidity': 0.42, 'citric_acid': 0.4,
#          'residual_sugar': 2.3, 'chlorides': 0.073, 'free_sulfur_dioxide': 12.0,
#          'total_sulfur_dioxide': 40.0, 'density': 0.9970, 'pH': 3.30,
#          'sulphates': 0.70, 'alcohol': 11.5},
#         # Vino premium esperado
#         {'fixed_acidity': 9.1, 'volatile_acidity': 0.35, 'citric_acid': 0.5,
#          'residual_sugar': 2.5, 'chlorides': 0.060, 'free_sulfur_dioxide': 8.0,
#          'total_sulfur_dioxide': 22.0, 'density': 0.9965, 'pH': 3.20,
#          'sulphates': 0.85, 'alcohol': 13.2}
#     ])
#     ```
# 29. Mostrar predicción + probabilidad de cada uno con `predict_proba()`.
# 30. ¿Las predicciones tienen sentido (los premium deberían dar mayor probabilidad de ser "buenos")?

# %%
# FASE 7 — Producción + predicción de vinos nuevos 👇

# %% [markdown]
# ## FASE 8 — Informe final para la bodega
#
# ### Tareas
#
# 31. Escribir en una celda markdown un **informe ejecutivo** para el dueño de la bodega que incluya:
#     - **Qué problema resolviste** (1 línea)
#     - **Qué modelo elegiste y por qué** (1-2 frases)
#     - **Métricas finales** (F1, precision, recall, AUC)
#     - **3 propiedades químicas que la bodega debe vigilar** según el modelo
#     - **Limitaciones honestas** del modelo (no ocultarlas)
#     - **Recomendación de uso:** ¿el modelo reemplaza a los catadores o los apoya?

# %% [markdown]
# # 📋 Informe ejecutivo — Bodega Vino Tinto
#
# *(Escribe tu informe aquí, basándote en los resultados del análisis)*
#
# ---
#
# **Problema resuelto:**
# ...
#
# **Modelo elegido:**
# ...
#
# **Métricas finales:**
# - F1: ...
# - Precision: ...
# - Recall: ...
# - AUC: ...
#
# **3 propiedades químicas clave para hacer un buen vino:**
# 1. ...
# 2. ...
# 3. ...
#
# **Limitaciones:**
# ...
#
# **Recomendación de uso:**
# ...

# %% [markdown]
# ---
# ## 🏁 Cierre de la semana de clasificación
#
# Felicitaciones — esta semana cubrieron los 4 modelos clásicos de clasificación, aprendieron a evaluar correctamente con métricas que entienden el desbalance, y armaron un proyecto integrador completo.
#
# ### 🔜 Próxima semana — Semana 8 (8–13 junio)
#
# - **Lun 8:** Cierre conceptual y siguientes pasos
# - **Mar 9:** Introducción a PostgreSQL
# - **Mié 10:** Actividades core — Challenge Técnico
# - **Jue 11:** Simulacro de examen
# - **Vie 12:** Simulacro de examen + repaso integrador
# - **Sáb 13:** 📝 **Examen Intento 1**
#
# Nos vemos 🚀
