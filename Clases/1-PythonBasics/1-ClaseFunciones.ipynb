# %% [markdown]
# <br/>
# <img src="images/LOGO-CORREO_x.png" alt="SkillNest" width="280px" align="left"/>
# <img src="images/LOGO-CORREO_x.png" alt="SkillNest" width="280px" align="right"/>
# <div align="center">
# <h2>Bootcamp Data Science SONDA — Módulo 1</h2><br/>
# <h1>Clase Especial — Funciones, Repaso y Pandas</h1>
# <h3>Listas · Tuplas · Diccionarios · Condicionales · Funciones · Pandas</h3>
# <br/>
# <b>Instructor:</b> Jesús Ortiz &nbsp;|&nbsp; <b>Horario:</b> 18:00 – 23:00 hrs
# </div>

# %% [markdown]
# ## 📋 Agenda de hoy
#
# | Horario | Bloque | Temas |
# |---------|--------|-------|
# | 18:00 – 18:45 | **1 — Funciones** | def, parámetros, return, defaults, lambda |
# | 18:45 – 19:15 | **2 — Librerías** | import, math, random, datetime |
# | 19:15 – 20:00 | **3 — Ejercicios Python** | Listas, tuplas, dicts, condicionales, funciones |
# | 20:00 – 20:10 | ☕ Break | |
# | 20:10 – 20:45 | **4 — Repaso Pandas** | Creación de DF, acceso, sub-DF, filtros |
# | 20:45 – 22:00 | **5 — Ejercicios Pandas** | Práctica guiada con datasets reales |
# | 22:00 – 23:00 | **6 — Taller** | Desafío integrador |

# %% [markdown]
# ---
# <div style="background:linear-gradient(90deg,#6C3CE1,#00C9A7);padding:2px;border-radius:10px">
# <div style="background:#0F0F1A;border-radius:9px;padding:20px 30px">
# <h1 style="color:white;margin:0">⚙️ Bloque 1 — Funciones</h1>
# <h3 style="color:#AAA;margin:0">18:00 – 18:45</h3>
# </div>
# </div>

# %% [markdown]
# # ¿Qué es una función?

# %% [markdown]
# Una función es un **bloque de código reutilizable** con nombre. Piénsala como una **receta**:
# - La *receta* tiene un nombre, ingredientes (parámetros) y produce un resultado (return)
# - Puedes usarla cuantas veces quieras sin reescribir el código
#
# ```python
# def nombre_funcion(parametro1, parametro2):
#     # código
#     return resultado
# ```
#
# > **¿Por qué usar funciones?**
# > - ♻️ No repetir código (principio DRY: Don't Repeat Yourself)
# > - 🧩 Dividir problemas grandes en partes pequeñas
# > - 🧪 Facilitar pruebas y corrección de errores

# %% [markdown]
# # Función básica con `return`

# %%
# Función que calcula el área de un rectángulo
def area_rectangulo(base, altura):
    area = base * altura
    return area

# Llamar (invocar) la función
resultado = area_rectangulo(5, 3)
print(f"Área: {resultado}")

# También se puede usar directamente
print(f"Área: {area_rectangulo(10, 4)}")
print(f"Área: {area_rectangulo(2.5, 8)}")

# %% [markdown]
# # Función sin `return` (procedimiento)

# %%
# No toda función necesita retornar un valor
# Algunas solo ejecutan acciones

def saludar(nombre, hora):
    if hora < 12:
        saludo = "Buenos días"
    elif hora < 20:
        saludo = "Buenas tardes"
    else:
        saludo = "Buenas noches"
    print(f"{saludo}, {nombre}! 👋")

saludar("Ana", 10)
saludar("Luis", 15)
saludar("María", 21)

# Si no hay return, Python retorna None implícitamente
resultado = saludar("Pedro", 9)
print(f"Retorna: {resultado}")   # None

# %% [markdown]
# # Parámetros por defecto

# %%
# Los parámetros con default son opcionales al llamar la función
def calcular_descuento(precio, descuento=0.10, incluir_iva=True):
    precio_con_descuento = precio * (1 - descuento)
    if incluir_iva:
        precio_final = precio_con_descuento * 1.19
    else:
        precio_final = precio_con_descuento
    return round(precio_final, 2)

# Llamadas con distintas combinaciones
print(calcular_descuento(10_000))               # usa defaults: 10% desc + IVA
print(calcular_descuento(10_000, 0.20))         # 20% desc + IVA
print(calcular_descuento(10_000, 0.15, False))  # 15% desc sin IVA
print(calcular_descuento(10_000, incluir_iva=False))  # solo cambia IVA

# %% [markdown]
# # Múltiples valores de retorno

# %%
# Python permite retornar varios valores como tupla
def estadisticas(numeros):
    total    = sum(numeros)
    promedio = total / len(numeros)
    maximo   = max(numeros)
    minimo   = min(numeros)
    return promedio, maximo, minimo   # retorna tupla

notas = [6.5, 4.8, 7.0, 5.5, 6.1]

# Desempaquetar el resultado
prom, alto, bajo = estadisticas(notas)
print(f"Promedio: {prom:.2f}")
print(f"Más alta: {alto}")
print(f"Más baja: {bajo}")

# O guardar la tupla completa
resultado = estadisticas(notas)
print(f"\nTodo junto: {resultado}")

# %% [markdown]
# # Funciones que llaman a otras funciones

# %%
# Las funciones pueden llamarse entre sí — así se construyen programas grandes

def es_par(n):
    return n % 2 == 0

def clasificar_numero(n):
    if n == 0:
        return "cero"
    elif n < 0:
        return "negativo"
    elif es_par(n):         # llama a otra función
        return "par positivo"
    else:
        return "impar positivo"

def analizar_lista(numeros):
    resultado = {}
    for n in numeros:
        resultado[n] = clasificar_numero(n)  # llama a otra función
    return resultado

lista = [-3, 0, 4, 7, -8, 15, 2]
for numero, categoria in analizar_lista(lista).items():
    print(f"  {numero:4d} → {categoria}")

# %% [markdown]
# # Funciones lambda (función anónima)

# %%
# Lambda: función de una línea, sin nombre propio
# Útil para operaciones simples o como argumento de otra función

# Función normal
def doble(x):
    return x * 2

# Equivalente con lambda
doble_lambda = lambda x: x * 2

print(doble(5))        # 10
print(doble_lambda(5)) # 10

# Uso más común: ordenar con una clave personalizada
alumnos = [
    {"nombre": "Ana",   "nota": 6.8},
    {"nombre": "Luis",  "nota": 4.2},
    {"nombre": "María", "nota": 7.0},
    {"nombre": "Pedro", "nota": 5.5},
]

# Ordenar por nota de mayor a menor
ordenados = sorted(alumnos, key=lambda a: a["nota"], reverse=True)
for a in ordenados:
    print(f"  {a['nombre']:<8} {a['nota']}")

# %% [markdown]
# # Scope: variables locales vs globales

# %%
# Las variables dentro de una función son LOCALES — no existen fuera

contador_global = 0  # variable global

def incrementar():
    local_var = 100  # solo existe dentro de la función
    return local_var

print(incrementar())   # 100
# print(local_var)     # ❌ NameError: local_var no existe aquí

# Para modificar una global dentro de una función (poco recomendado)
def resetear():
    global contador_global
    contador_global = 0

contador_global = 5
print(f"Antes:  {contador_global}")
resetear()
print(f"Después: {contador_global}")

# ✅ Mejor práctica: pasar y retornar valores
def incrementar_v2(contador, cantidad=1):
    return contador + cantidad

c = 0
c = incrementar_v2(c)
c = incrementar_v2(c, 5)
print(f"Contador: {c}")

# %% [markdown]
# ---
# <div style="background:linear-gradient(90deg,#6C3CE1,#00C9A7);padding:2px;border-radius:10px">
# <div style="background:#0F0F1A;border-radius:9px;padding:20px 30px">
# <h1 style="color:white;margin:0">📦 Bloque 2 — Librerías de Python</h1>
# <h3 style="color:#AAA;margin:0">18:45 – 19:15</h3>
# </div>
# </div>

# %% [markdown]
# # ¿Qué es una librería?

# %% [markdown]
# Una **librería** es un conjunto de funciones y clases escritas por alguien más que podemos reutilizar.
#
# ```python
# import libreria                    # importar toda la librería
# import libreria as alias           # con alias (más corto)
# from libreria import funcion       # importar solo una función
# from libreria import func1, func2  # importar varias
# ```
#
# > 📦 Las librerías que vienen con Python se llaman **stdlib** (standard library).
# > Las externas como `pandas` se instalan con `pip install nombre`.

# %% [markdown]
# # `math` — Matemáticas

# %%
import math

print(f"π         = {math.pi:.6f}")
print(f"e         = {math.e:.6f}")
print(f"√144      = {math.sqrt(144)}")
print(f"log₁₀(100)= {math.log10(100)}")
print(f"log₂(8)   = {math.log2(8)}")
print(f"ceil(4.1) = {math.ceil(4.1)}")   # redondear hacia arriba
print(f"floor(4.9)= {math.floor(4.9)}")  # redondear hacia abajo
print(f"abs(-7)   = {abs(-7)}")          # valor absoluto (builtin)
print(f"2^10      = {math.pow(2, 10):.0f}")
print(f"sin(90°)  = {math.sin(math.radians(90)):.2f}")

# %% [markdown]
# # `random` — Aleatoriedad

# %%
import random

random.seed(42)  # fija la semilla — resultados reproducibles

print(f"Float [0,1):     {random.random():.4f}")
print(f"Entero [1,10]:   {random.randint(1, 10)}")
print(f"Float [5, 15]:   {random.uniform(5, 15):.2f}")

opciones = ["Rock", "Papel", "Tijera"]
print(f"choice:          {random.choice(opciones)}")

lista = list(range(1, 11))
random.shuffle(lista)
print(f"shuffle:         {lista}")

muestra = random.sample(range(1, 50), 6)
print(f"Loto (6/49):     {sorted(muestra)}")

# %% [markdown]
# # `datetime` — Fechas y horas

# %%
from datetime import datetime, date, timedelta

# Fecha y hora actual
ahora = datetime.now()
print(f"Ahora:        {ahora}")
print(f"Fecha:        {ahora.date()}")
print(f"Hora:         {ahora.time()}")
print(f"Año:          {ahora.year}")
print(f"Día semana:   {ahora.strftime('%A')}")  # nombre del día
print(f"Formato:      {ahora.strftime('%d/%m/%Y %H:%M')}")

# Operaciones con fechas
hoy = date.today()
cumple = date(2025, 12, 25)  # Navidad
dias_para_navidad = (cumple - hoy).days
print(f"\nDías para Navidad 2025: {dias_para_navidad}")

hace_30_dias = hoy - timedelta(days=30)
print(f"Hace 30 días: {hace_30_dias}")

# %% [markdown]
# ---
# <div style="background:linear-gradient(90deg,#6C3CE1,#00C9A7);padding:2px;border-radius:10px">
# <div style="background:#0F0F1A;border-radius:9px;padding:20px 30px">
# <h1 style="color:white;margin:0">💪 Bloque 3 — Ejercicios Python</h1>
# <h3 style="color:#AAA;margin:0">19:15 – 20:00</h3>
# </div>
# </div>

# %% [markdown]
# > Resuelve cada ejercicio en su celda. Los ejercicios son **independientes** — si te trabas en uno, pasa al siguiente.

# %% [markdown]
# ## Listas

# %% [markdown]
# ### 🔹 Ejercicio L1 — Estadísticas sin funciones built-in
#
# Dada la lista: `temperaturas = [23.1, 19.8, 25.4, 17.2, 30.0, 22.5, 18.9, 27.3, 21.1, 24.6]`
#
# **Sin usar** `max()`, `min()`, `sum()`:
# 1. Calcula el promedio
# 2. Encuentra el valor máximo y mínimo
# 3. Cuenta cuántos valores están sobre el promedio
# 4. Imprime un reporte con los resultados

# %%
# L1
temperaturas = [23.1, 19.8, 25.4, 17.2, 30.0, 22.5, 18.9, 27.3, 21.1, 24.6]

# %% [markdown]
# ### 🔹 Ejercicio L2 — Manipulación de listas
#
# Dada: `palabras = ["hola", "mundo", "data", "science", "python", "pandas"]`
#
# 1. Agrega `"machine"` y `"learning"` al final
# 2. Inserta `"bootcamp"` en la posición 2
# 3. Elimina `"mundo"`
# 4. Ordena la lista alfabéticamente
# 5. Crea una nueva lista con solo las palabras de más de 4 letras usando list comprehension
# 6. Imprime la lista final y la lista filtrada

# %%
# L2
palabras = ['hola', 'mundo', 'data', 'science', 'python', 'pandas']

# %% [markdown]
# ### 🔹 Ejercicio L3 — Matrices (listas de listas)
#
# Tenemos las notas de 4 alumnos en 3 pruebas:
# ```python
# notas = [
#     [6.5, 5.8, 7.0],   # Alumno 1
#     [4.2, 6.1, 5.5],   # Alumno 2
#     [7.0, 6.8, 6.9],   # Alumno 3
#     [3.8, 4.5, 5.0],   # Alumno 4
# ]
# ```
# 1. Calcula el promedio de cada alumno
# 2. Identifica qué alumnos aprobaron (promedio ≥ 4.0)
# 3. Calcula el promedio de la clase (promedio de todos los promedios)
# 4. ¿Cuál fue la nota más alta en toda la tabla?

# %%
# L3
notas = [
    [6.5, 5.8, 7.0],
    [4.2, 6.1, 5.5],
    [7.0, 6.8, 6.9],
    [3.8, 4.5, 5.0],
]

# %% [markdown]
# ## Tuplas

# %% [markdown]
# ### 🔹 Ejercicio T1 — Coordenadas geográficas
#
# Tienes las coordenadas (latitud, longitud) de 5 ciudades de Chile:
# ```python
# ciudades = [
#     ("Santiago",    (-33.45, -70.67)),
#     ("Valparaíso",  (-33.05, -71.62)),
#     ("Concepción",  (-36.82, -73.05)),
#     ("La Serena",   (-29.91, -71.25)),
#     ("Antofagasta", (-23.65, -70.40)),
# ]
# ```
# 1. Imprime cada ciudad con su latitud y longitud formateadas a 2 decimales
# 2. Encuentra la ciudad más al norte (latitud más cercana a 0, menos negativa)
# 3. Encuentra la ciudad más al sur
# 4. **Bonus:** Calcula la distancia aproximada entre Santiago y Concepción
#    usando la fórmula: `distancia ≈ √((lat2-lat1)² + (lon2-lon1)²) × 111`
#    (111 km por grado)

# %%
# T1
import math
ciudades = [
    ("Santiago",    (-33.45, -70.67)),
    ("Valparaíso",  (-33.05, -71.62)),
    ("Concepción",  (-36.82, -73.05)),
    ("La Serena",   (-29.91, -71.25)),
    ("Antofagasta", (-23.65, -70.40)),
]

# %% [markdown]
# ## Diccionarios

# %% [markdown]
# ### 🔹 Ejercicio D1 — Inventario de tienda
#
# ```python
# inventario = {
#     "manzana":  {"precio": 990,   "stock": 150, "categoria": "fruta"},
#     "leche":    {"precio": 1290,  "stock": 80,  "categoria": "lacteo"},
#     "pan":      {"precio": 1500,  "stock": 40,  "categoria": "panaderia"},
#     "queso":    {"precio": 4990,  "stock": 25,  "categoria": "lacteo"},
#     "naranja":  {"precio": 790,   "stock": 200, "categoria": "fruta"},
#     "yogurt":   {"precio": 1890,  "stock": 60,  "categoria": "lacteo"},
# }
# ```
# 1. Calcula el valor total del inventario (precio × stock para cada producto)
# 2. Lista los productos con stock menor a 50
# 3. Encuentra el producto más caro y el más barato
# 4. Agrupa los productos por categoría e imprime cada grupo

# %%
# D1
inventario = {
    "manzana":  {"precio": 990,   "stock": 150, "categoria": "fruta"},
    "leche":    {"precio": 1290,  "stock": 80,  "categoria": "lacteo"},
    "pan":      {"precio": 1500,  "stock": 40,  "categoria": "panaderia"},
    "queso":    {"precio": 4990,  "stock": 25,  "categoria": "lacteo"},
    "naranja":  {"precio": 790,   "stock": 200, "categoria": "fruta"},
    "yogurt":   {"precio": 1890,  "stock": 60,  "categoria": "lacteo"},
}

# %% [markdown]
# ### 🔹 Ejercicio D2 — Contador de palabras
#
# Dada la siguiente frase, construye un diccionario que cuente cuántas veces aparece cada palabra.
# No uses `collections.Counter` — hazlo con un `for` y un `dict`.
#
# ```python
# frase = "el data science es el arte de extraer conocimiento de los datos y el conocimiento es poder"
# ```
# 1. Crea el diccionario de frecuencias
# 2. Imprime las 3 palabras más repetidas
# 3. ¿Cuántas palabras únicas hay?
# 4. Elimina del conteo las palabras de 2 letras o menos

# %%
# D2
frase = "el data science es el arte de extraer conocimiento de los datos y el conocimiento es poder"

# %% [markdown]
# ## Condicionales

# %% [markdown]
# ### 🔹 Ejercicio C1 — Calculadora de impuestos
#
# En Chile, el impuesto a la renta se calcula por tramos (2024):
#
# | Tramo | Renta mensual | Tasa |
# |-------|--------------|------|
# | 1 | Hasta $772.000 | 0% |
# | 2 | $772.001 – $1.715.000 | 4% |
# | 3 | $1.715.001 – $2.858.000 | 8% |
# | 4 | $2.858.001 – $3.975.000 | 13.5% |
# | 5 | Más de $3.975.000 | 23% |
#
# Escribe un programa que:
# 1. Pida la renta mensual con `input()`
# 2. Calcule el impuesto y la renta líquida
# 3. Muestre un resumen claro con el tramo, tasa, impuesto y líquido

# %%
# C1 — ▶️ Ejecutar manualmente (usa input)

# %% [markdown]
# ## Funciones

# %% [markdown]
# ### 🔹 Ejercicio F1 — Librería de funciones matemáticas
#
# Crea las siguientes funciones **sin usar las funciones built-in correspondientes**:
#
# 1. `mi_max(lista)` — retorna el valor máximo
# 2. `mi_min(lista)` — retorna el valor mínimo
# 3. `mi_suma(lista)` — retorna la suma de todos los elementos
# 4. `mi_promedio(lista)` — retorna el promedio
# 5. `mi_mediana(lista)` — retorna la mediana (el valor del medio al ordenar)
#
# Prueba cada función con: `[8, 3, 15, 2, 9, 1, 7, 4, 12, 6]`
# Verifica que coinciden con `max()`, `min()`, `sum()` de Python.

# %%
# F1

# %% [markdown]
# ### 🔹 Ejercicio F2 — Procesador de texto
#
# Crea una función `analizar_texto(texto)` que reciba un string y retorne un diccionario con:
# - `"palabras"`: número de palabras
# - `"caracteres"`: número de caracteres (sin espacios)
# - `"oraciones"`: número de oraciones (termina en `.`, `!` o `?`)
# - `"palabra_mas_larga"`: la palabra más larga
# - `"palabras_unicas"`: número de palabras distintas (ignorar mayúsculas)
#
# Pruébala con al menos 2 textos distintos.

# %%
# F2
def analizar_texto(texto):
    pass  # reemplaza con tu código

texto1 = "Python es genial. Los datos son el nuevo petróleo. ¡Aprender Data Science es increíble!"
print(analizar_texto(texto1))

# %% [markdown]
# ### 🔹 Ejercicio F3 — Funciones encadenadas
#
# Construye un mini-sistema de calificaciones con estas funciones:
#
# 1. `letra_nota(nota)` — convierte nota numérica a letra:
#    - 6.5–7.0 → `"A"`, 5.5–6.4 → `"B"`, 4.0–5.4 → `"C"`, < 4.0 → `"F"`
#
# 2. `resumen_alumno(nombre, notas)` — recibe nombre y lista de notas, retorna dict con:
#    - promedio, nota máxima, nota mínima, letra (usando `letra_nota`), estado ("Aprobado"/"Reprobado")
#
# 3. `reporte_curso(alumnos)` — recibe lista de dicts `{"nombre": ..., "notas": [...]}`, imprime:
#    - Tabla con nombre, promedio, letra, estado
#    - Promedio del curso
#    - Número de aprobados y reprobados
#
# Prueba con al menos 4 alumnos.

# %%
# F3
def letra_nota(nota):
    pass

def resumen_alumno(nombre, notas):
    pass

def reporte_curso(alumnos):
    pass

# Datos de prueba
curso = [
    {"nombre": "Ana García",    "notas": [6.8, 7.0, 6.5, 6.9]},
    {"nombre": "Luis Pérez",    "notas": [4.2, 5.0, 4.8, 3.9]},
    {"nombre": "María López",   "notas": [5.5, 6.1, 5.8, 6.0]},
    {"nombre": "Carlos Soto",   "notas": [3.5, 4.0, 3.8, 4.2]},
    {"nombre": "Sofía Muñoz",   "notas": [7.0, 6.9, 7.0, 6.8]},
]

reporte_curso(curso)

# %% [markdown]
# ---
# <div style="background:linear-gradient(90deg,#6C3CE1,#00C9A7);padding:2px;border-radius:10px">
# <div style="background:#0F0F1A;border-radius:9px;padding:20px 30px">
# <h1 style="color:white;margin:0">🐼 Bloque 4 — Repaso Rápido — Pandas</h1>
# <h3 style="color:#AAA;margin:0">20:10 – 20:45</h3>
# </div>
# </div>

# %% [markdown]
# > ☕ Después del break — recordemos lo de ayer en 5 minutos antes de los ejercicios.

# %% [markdown]
# # Resumen: lo que ya sabemos de Pandas

# %% [markdown]
# ```python
# import pandas as pd
#
# # Crear DataFrames
# df = pd.DataFrame({"col1": [...], "col2": [...]})   # desde diccionario
# df = pd.read_csv("archivo.csv")                      # desde archivo
#
# # Explorar
# df.head(n)     df.tail(n)     df.shape     df.dtypes
# df.info()      df.describe()
#
# # Seleccionar
# df["col"]                    # una columna → Series
# df[["col1", "col2"]]         # varias columnas → DataFrame
# df.loc[filas, columnas]      # por nombre
# df.iloc[filas, columnas]     # por posición
#
# # Filtrar
# df[df["col"] == valor]                          # igual
# df[df["col"] > valor]                           # mayor que
# df[(cond1) & (cond2)]                           # Y lógico
# df[(cond1) | (cond2)]                           # O lógico
# df[~condicion]                                  # negación
# df[df["col"].isin([v1, v2])]                    # en lista
# df[df["col"].str.contains("texto")]             # contiene texto
# ```

# %%
import pandas as pd

# Cargamos el dataset de Pokémon que ya conocemos
df = pd.read_csv("../2-Pandas/data/pokemon.csv")
print(f"Shape: {df.shape}")
df.head()

# %% [markdown]
# ---
# <div style="background:linear-gradient(90deg,#6C3CE1,#00C9A7);padding:2px;border-radius:10px">
# <div style="background:#0F0F1A;border-radius:9px;padding:20px 30px">
# <h1 style="color:white;margin:0">🔬 Bloque 5 — Ejercicios Pandas</h1>
# <h3 style="color:#AAA;margin:0">20:45 – 22:00</h3>
# </div>
# </div>

# %% [markdown]
# ### 🔹 Ejercicio P1 — Creación de DataFrame
#
# Crea desde cero un DataFrame con la información del equipo de fútbol favorito (o inventado).
# Debe tener al menos 8 jugadores y las columnas:
# `nombre`, `posicion`, `edad`, `goles_temporada`, `minutos_jugados`, `titular`
#
# Luego:
# 1. Muestra los titulares con sus goles
# 2. Calcula el promedio de edad del equipo
# 3. Encuentra al goleador (más goles)
# 4. ¿Cuántos minutos en promedio jugaron los titulares vs suplentes?

# %%
# P1
import pandas as pd

# Crea tu DataFrame aquí:

# %% [markdown]
# ### 🔹 Ejercicio P2 — Exploración del Titanic
#
# Carga `../2-Pandas/data/titanic.csv` y responde:
#
# 1. ¿Cuántos pasajeros había en cada clase (`Pclass`)? Usa `value_counts()`
# 2. ¿Cuál era la edad promedio de los pasajeros? (ignorando nulos)
# 3. Muestra las columnas `Name`, `Sex`, `Age`, `Pclass`, `Survived` de los primeros 10
# 4. ¿Cuántos pasajeros tienen edad desconocida (nula)?
# 5. Usa `describe()` solo en las columnas numéricas relevantes: `Age`, `Fare`, `SibSp`

# %%
# P2
import pandas as pd
df = pd.read_csv('../2-Pandas/data/titanic.csv')

# %% [markdown]
# ### 🔹 Ejercicio P3 — Filtros con Pokémon
#
# Carga `../2-Pandas/data/pokemon.csv` y crea **sub-DataFrames** guardados en variables:
#
# 1. `df_legendarios` — solo pokémon legendarios, mostrando `Name`, `Type 1`, `Total`
# 2. `df_poderosos` — pokémon con `Total` > 580 que **no** sean legendarios
# 3. `df_rapidos_fragiles` — `Speed` > 100 pero `Defense` < 50 (ordenados por Speed desc)
# 4. `df_gen1_agua` — pokémon de tipo Agua de la Generación 1
# 5. Para cada sub-DataFrame, imprime cuántos registros tiene
#
# **Bonus:** ¿Cuál es el pokémon más poderoso (mayor `Total`) de cada tipo en `df_poderosos`?

# %%
# P3
import pandas as pd
df = pd.read_csv('../2-Pandas/data/pokemon.csv')

# %% [markdown]
# ### 🔹 Ejercicio P4 — Funciones + Pandas
#
# Combina lo aprendido hoy: crea funciones que trabajen con DataFrames.
#
# ```python
# import pandas as pd
# df = pd.read_csv('../2-Pandas/data/pokemon.csv')
# ```
#
# Escribe estas funciones:
#
# 1. `tipo_mas_fuerte(df)` — retorna el tipo (`Type 1`) con el mayor `Attack` promedio
#
# 2. `buscar_pokemon(df, nombre)` — recibe un nombre (o parte de él), retorna todos los pokémon que coincidan con sus stats completas
#
# 3. `comparar_tipos(df, tipo1, tipo2)` — recibe dos tipos y retorna un dict comparando:
#    - `HP` promedio de cada tipo
#    - `Attack` promedio de cada tipo
#    - `Speed` promedio de cada tipo
#    - Cuál gana en cada categoría
#
# Prueba cada función.

# %%
# P4
import pandas as pd
df = pd.read_csv('../2-Pandas/data/pokemon.csv')

def tipo_mas_fuerte(df):
    pass

def buscar_pokemon(df, nombre):
    pass

def comparar_tipos(df, tipo1, tipo2):
    pass

# Pruebas:
print(tipo_mas_fuerte(df))
print(buscar_pokemon(df, 'Char'))
print(comparar_tipos(df, 'Fire', 'Water'))

# %% [markdown]
# ---
# <div style="background:linear-gradient(90deg,#6C3CE1,#00C9A7);padding:2px;border-radius:10px">
# <div style="background:#0F0F1A;border-radius:9px;padding:20px 30px">
# <h1 style="color:white;margin:0">🏆 Bloque 6 — Desafío Final — Taller</h1>
# <h3 style="color:#AAA;margin:0">22:00 – 23:00</h3>
# </div>
# </div>

# %% [markdown]
# ## Sistema de análisis de un torneo Pokémon
#
# Construye un sistema completo usando **funciones** y **pandas** juntos.
#
# ### Contexto
# Eres el analista de un torneo de Pokémon. Tienes el dataset completo y debes construir herramientas para que los entrenadores elijan su equipo.
#
# ---
#
# ### Parte 1 — Funciones de análisis (Python puro)
#
# ```python
# import pandas as pd
# df = pd.read_csv('../2-Pandas/data/pokemon.csv')
# ```
#
# **Función 1:** `equipo_balanceado(df, tipo)`
# Dado un tipo, retorna los 6 mejores pokémon de ese tipo balanceando ataque, defensa y velocidad (suma de los tres dividida por 3).
#
# **Función 2:** `debilidades(tipo)`
# Retorna una lista con los tipos contra los que ese tipo es "débil" (puedes definir 3-4 relaciones simples, ej: Fuego < Agua, Agua < Planta, Planta < Fuego).
#
# **Función 3:** `mejor_equipo_contra(df, tipo_rival)`
# Dado el tipo del equipo rival, sugiere los 3 mejores pokémon para enfrentarlos (del tipo que les gana).
#
# ---
#
# ### Parte 2 — Reporte final
#
# Crea una función `reporte_torneo(df)` que imprima:
# 1. El tipo con mayor `Total` promedio
# 2. El tipo con mayor `Speed` promedio
# 3. Top 5 pokémon por `Total` (no legendarios)
# 4. La generación con más pokémon legendarios
# 5. El pokémon más equilibrado (menor diferencia entre su mayor y menor stat)
#
# ---
#
# ### Parte 3 — Bonus
# Agrega al DataFrame una columna `"rol"` según sus estadísticas:
# - `Attack` > `Defense` y `Speed` > 80 → `"Atacante veloz"`
# - `Defense` > `Attack` y `HP` > 80 → `"Tanque"`
# - `Sp. Atk` > `Attack` y `Sp. Atk` > `Defense` → `"Mago"`
# - Otros → `"Equilibrado"`
#
# ¿Cuántos pokémon hay de cada rol?

# %%
# Desafío Final
import pandas as pd

df = pd.read_csv('../2-Pandas/data/pokemon.csv')

# Parte 1
def equipo_balanceado(df, tipo):
    pass

def debilidades(tipo):
    pass

def mejor_equipo_contra(df, tipo_rival):
    pass

# Parte 2
def reporte_torneo(df):
    pass

# Parte 3 — columna "rol"


# Pruebas:
print(equipo_balanceado(df, 'Fire'))
print(debilidades('Fire'))
print(mejor_equipo_contra(df, 'Fire'))
reporte_torneo(df)

# %%
from IPython.core.display import HTML
HTML("""<style>
.output_png { display: table-cell; text-align: center; vertical-align: middle; }
table { border-collapse: collapse; }
</style>""")
