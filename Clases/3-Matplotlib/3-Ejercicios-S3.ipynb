# %% [markdown]
# <div style="display:flex; align-items:center; justify-content:space-between; background:linear-gradient(135deg,#0F0F1A 0%,#1A1A2E 100%); padding:28px 36px; border-radius:14px; margin-bottom:16px;">
#   <div>
#     <h1 style="color:white; margin:0; font-size:2em; font-weight:900;">Ejercicios S3 · Matplotlib y Visualización</h1>
#     <p style="color:#00C9A7; margin:8px 0 0;">Data Science Fundamentals — SKILLNEST</p>
#     <p style="color:#888; margin:4px 0 0; font-size:0.9em;">Practica histogramas, box plots, subplots y Seaborn con datasets reales</p>
#   </div>
#   <img src="images/LOGO-CORREO_x.png" width="120"/>
# </div>

# %% [markdown]
# ## Instrucciones
#
# - Trabaja en orden — cada ejercicio construye sobre el anterior
# - Carga los datasets **una sola vez** en la celda de setup y reutiliza las variables
# - Los gráficos deben tener siempre: título, etiquetas de ejes, y leyenda si aplica
# - Puedes usar `matplotlib` o `seaborn` salvo que se indique lo contrario
#
# ---

# %% [markdown]
# ## Setup — Ejecuta esta celda primero

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Datasets
df = pd.read_csv("../2-Pandas/data/pokemon.csv")
titanic = pd.read_csv("../2-Pandas/data/titanic.csv")

print(f"Pokemon: {df.shape}  |  Titanic: {titanic.shape}")

# %% [markdown]
# <div style="background:linear-gradient(90deg,#6C3CE1,#1A1A2E); padding:16px 24px; border-radius:10px; margin:24px 0 12px;">
#   <h3 style="color:white; margin:0;">📊 Clase 1 — Fundamentos de Matplotlib</h3>
#   <p style="color:rgba(255,255,255,0.8); margin:4px 0 0; font-size:0.95em;">Líneas, scatter y barras</p>
# </div>

# %% [markdown]
# <div style="background:#1A1A2E; border-left:4px solid #6C3CE1; padding:16px 22px; border-radius:8px; margin:14px 0;">
#   <div style="display:flex; justify-content:space-between;">
#     <span style="color:#6C3CE1; font-weight:700;">Ejercicio C1.1</span>
#     <span style="background:#6C3CE1; color:white; padding:2px 10px; border-radius:12px; font-size:0.82em;">10 pts pts</span>
#   </div>
#   <p style="color:white; font-weight:600; margin:8px 0 6px;">Evolución de stats por generación (líneas)</p>
#   <p style="color:#CCC; margin:0; font-size:0.95em;">Crea una figura con 2 líneas superpuestas: el promedio de 'Attack' por generación y el promedio de 'Defense' por generación. Usa colores distintos para cada línea, marcadores, grid y leyenda. Añade una anotación de texto señalando la generación con mayor diferencia entre Attack y Defense.</p>
# </div>

# %%
# C1.1 — Tu código aquí:

# %% [markdown]
# <div style="background:#1A1A2E; border-left:4px solid #6C3CE1; padding:16px 22px; border-radius:8px; margin:14px 0;">
#   <div style="display:flex; justify-content:space-between;">
#     <span style="color:#6C3CE1; font-weight:700;">Ejercicio C1.2</span>
#     <span style="background:#6C3CE1; color:white; padding:2px 10px; border-radius:12px; font-size:0.82em;">10 pts pts</span>
#   </div>
#   <p style="color:white; font-weight:600; margin:8px 0 6px;">Ranking de tipos — barras horizontales</p>
#   <p style="color:#CCC; margin:0; font-size:0.95em;">Crea un gráfico de barras HORIZONTALES con el Top 8 tipos (Type 1) por Stats Totales promedio. El tipo con mayor promedio debe ir arriba. Usa un gradiente de color (más oscuro = mayor valor). Incluye el valor numérico al final de cada barra.</p>
# </div>

# %%
# C1.2 — Tu código aquí:

# %% [markdown]
# <div style="background:#1A1A2E; border-left:4px solid #6C3CE1; padding:16px 22px; border-radius:8px; margin:14px 0;">
#   <div style="display:flex; justify-content:space-between;">
#     <span style="color:#6C3CE1; font-weight:700;">Ejercicio C1.3</span>
#     <span style="background:#6C3CE1; color:white; padding:2px 10px; border-radius:12px; font-size:0.82em;">15 pts pts</span>
#   </div>
#   <p style="color:white; font-weight:600; margin:8px 0 6px;">Scatter con 3 grupos</p>
#   <p style="color:#CCC; margin:0; font-size:0.95em;">Crea un scatter de 'Sp. Atk' (eje X) vs 'Sp. Def' (eje Y). Divide los pokémon en 3 grupos según su tipo de ataque predominante: 'Especial' si Sp. Atk > Attack, 'Físico' si Attack > Sp. Atk, 'Balanceado' si son iguales. Usa un color diferente por grupo, ajusta el tamaño según Total/10, y añade leyenda. ¿Qué patrón observas? Escríbelo en una celda de texto.</p>
# </div>

# %%
# C1.3 — Tu código aquí:

# %% [markdown]
# **Escribe aquí tu conclusión del scatter (C1.3):**
#
# > *Observación: ...*

# %% [markdown]
# <div style="background:linear-gradient(90deg,#00503E,#1A1A2E); padding:16px 24px; border-radius:10px; margin:24px 0 12px;">
#   <h3 style="color:white; margin:0;">📦 Clase 2 — Histogramas, Box Plots y Subplots</h3>
#   <p style="color:rgba(255,255,255,0.8); margin:4px 0 0; font-size:0.95em;">Distribuciones y composición</p>
# </div>

# %% [markdown]
# <div style="background:#1A1A2E; border-left:4px solid #6C3CE1; padding:16px 22px; border-radius:8px; margin:14px 0;">
#   <div style="display:flex; justify-content:space-between;">
#     <span style="color:#6C3CE1; font-weight:700;">Ejercicio C2.1</span>
#     <span style="background:#6C3CE1; color:white; padding:2px 10px; border-radius:12px; font-size:0.82em;">10 pts pts</span>
#   </div>
#   <p style="color:white; font-weight:600; margin:8px 0 6px;">Dashboard de distribuciones — 4 subplots</p>
#   <p style="color:#CCC; margin:0; font-size:0.95em;">Crea una figura 2×2 con los histogramas de HP, Attack, Defense y Speed. Cada subplot debe tener su color, el valor de media (línea vertical punteada) y los datos de media y desviación estándar en el título. Usa fig.suptitle para el título general.</p>
# </div>

# %%
# C2.1 — Tu código aquí:

# %% [markdown]
# <div style="background:#1A1A2E; border-left:4px solid #6C3CE1; padding:16px 22px; border-radius:8px; margin:14px 0;">
#   <div style="display:flex; justify-content:space-between;">
#     <span style="color:#6C3CE1; font-weight:700;">Ejercicio C2.2</span>
#     <span style="background:#6C3CE1; color:white; padding:2px 10px; border-radius:12px; font-size:0.82em;">12 pts pts</span>
#   </div>
#   <p style="color:white; font-weight:600; margin:8px 0 6px;">Comparación por generación — Box plot</p>
#   <p style="color:#CCC; margin:0; font-size:0.95em;">Crea un box plot que compare la distribución de 'Speed' para cada Generación (eje X = generación, eje Y = Speed). Colorea cada caja de forma distinta. Añade una línea horizontal en la mediana global de Speed. ¿En qué generación los pokémon son más rápidos en promedio?</p>
# </div>

# %%
# C2.2 — Tu código aquí:

# %% [markdown]
# <div style="background:#1A1A2E; border-left:4px solid #6C3CE1; padding:16px 22px; border-radius:8px; margin:14px 0;">
#   <div style="display:flex; justify-content:space-between;">
#     <span style="color:#6C3CE1; font-weight:700;">Ejercicio C2.3</span>
#     <span style="background:#6C3CE1; color:white; padding:2px 10px; border-radius:12px; font-size:0.82em;">13 pts pts</span>
#   </div>
#   <p style="color:white; font-weight:600; margin:8px 0 6px;">Histograma comparativo — Titanic</p>
#   <p style="color:#CCC; margin:0; font-size:0.95em;">Usando el dataset Titanic: (a) Crea 2 subplots con ejes X compartidos. Subplot superior: distribución de Age para supervivientes (Survived=1). Subplot inferior: distribución de Age para no supervivientes (Survived=0). Usa 25 bins, colores distintos y líneas en la mediana de cada grupo. (b) ¿Qué grupo de edad parece haber sobrevivido más?</p>
# </div>

# %%
# C2.3 — Tu código aquí:

# %% [markdown]
# **Conclusión C2.3 (b):**
#
# > *Observación: ...*

# %% [markdown]
# <div style="background:linear-gradient(90deg,#004080,#1A1A2E); padding:16px 24px; border-radius:10px; margin:24px 0 12px;">
#   <h3 style="color:white; margin:0;">🎨 Clase 3 — Seaborn y Explicabilidad</h3>
#   <p style="color:rgba(255,255,255,0.8); margin:4px 0 0; font-size:0.95em;">Heatmaps, pairplots y lectura crítica</p>
# </div>

# %% [markdown]
# <div style="background:#1A1A2E; border-left:4px solid #6C3CE1; padding:16px 22px; border-radius:8px; margin:14px 0;">
#   <div style="display:flex; justify-content:space-between;">
#     <span style="color:#6C3CE1; font-weight:700;">Ejercicio C3.1</span>
#     <span style="background:#6C3CE1; color:white; padding:2px 10px; border-radius:12px; font-size:0.82em;">12 pts pts</span>
#   </div>
#   <p style="color:white; font-weight:600; margin:8px 0 6px;">Seaborn histplot con KDE por tipo</p>
#   <p style="color:#CCC; margin:0; font-size:0.95em;">Usa sns.histplot para crear un gráfico que muestre la distribución de 'Total' para los tipos Fire, Water y Grass en el mismo eje, con KDE=True. Usa hue='Type 1' y palette personalizada. Añade título, etiquetas y coloca la leyenda dentro del gráfico.</p>
# </div>

# %%
# C3.1 — Tu código aquí:

# %% [markdown]
# <div style="background:#1A1A2E; border-left:4px solid #6C3CE1; padding:16px 22px; border-radius:8px; margin:14px 0;">
#   <div style="display:flex; justify-content:space-between;">
#     <span style="color:#6C3CE1; font-weight:700;">Ejercicio C3.2</span>
#     <span style="background:#6C3CE1; color:white; padding:2px 10px; border-radius:12px; font-size:0.82em;">13 pts pts</span>
#   </div>
#   <p style="color:white; font-weight:600; margin:8px 0 6px;">Heatmap de correlación — Titanic</p>
#   <p style="color:#CCC; margin:0; font-size:0.95em;">Calcula la correlación entre las columnas numéricas del Titanic (Age, Fare, Pclass, Survived, SibSp, Parch). Crea un heatmap con anotaciones y una paleta divergente. Identifica: ¿cuál variable tiene mayor correlación (positiva o negativa) con Survived? ¿Tiene sentido? Explica.</p>
# </div>

# %%
# C3.2 — Tu código aquí:

# %% [markdown]
# **Análisis C3.2:**
#
# > *La variable más correlacionada con Survived es ... porque ...*

# %% [markdown]
# <div style="background:#1A1A2E; border-left:4px solid #6C3CE1; padding:16px 22px; border-radius:8px; margin:14px 0;">
#   <div style="display:flex; justify-content:space-between;">
#     <span style="color:#6C3CE1; font-weight:700;">Ejercicio C3.3</span>
#     <span style="background:#6C3CE1; color:white; padding:2px 10px; border-radius:12px; font-size:0.82em;">15 pts pts</span>
#   </div>
#   <p style="color:white; font-weight:600; margin:8px 0 6px;">Dashboard final — Pokémon legendarios</p>
#   <p style="color:#CCC; margin:0; font-size:0.95em;">Crea una figura con 3 subplots sobre pokémon legendarios vs normales:<br>1. (sns.boxplot) Distribución de 'Total' por Legendary<br>2. (sns.barplot) Promedio de cada stat (HP, Attack, Defense, Sp. Atk, Sp. Def, Speed) por Legendary<br>   Pista: necesitas hacer melt o calcular medias por grupo<br>3. (scatter) Attack vs Speed, coloreado por Legendary, tamaño proporcional a HP/10<br>Añade título general y asegúrate de que sea auto-explicativo.</p>
# </div>

# %%
# C3.3 — Tu código aquí:

# %% [markdown]
# ---
#
# <div style="background:linear-gradient(135deg,#6C3CE1,#00C9A7); padding:22px 30px; border-radius:12px; margin:24px 0;">
#   <h2 style="color:white; margin:0; font-weight:900;">🏆 Desafío Final — Informe Visual Completo</h2>
#   <p style="color:rgba(255,255,255,0.9); margin:8px 0 0;">Crea un informe visual de 4 gráficos que responda la pregunta: <strong>"¿Qué hace a un equipo Pokémon ganador?"</strong></p>
# </div>
#
# **Restricciones:**
# - Todos los gráficos deben estar en **una sola figura** (layout 2×2)
# - El título general debe ser claro y descriptivo
# - Cada subplot debe contar UNA parte de la historia
#
# **Sugerencias de análisis (elige 4):**
# 1. ¿Cuáles son los tipos con mayor varianza en ataque? (box plot)
# 2. ¿Hay correlación entre Attack y Speed en pokémon de tipo Dragon vs Normal? (scatter)
# 3. ¿Cómo se distribuyen los legendarios por generación? (bar chart)
# 4. ¿Cuál es el stat más importante para determinar si un pokémon es legendario? (bar de medias)
# 5. ¿Los pokémon con Type 2 tienen mejores stats en promedio? (boxplot o barplot)
#
# **Al final agrega una celda de texto con:**
# - 3 conclusiones claras y concretas
# - Una recomendación: "Si pudiera elegir un equipo de 6 pokémon basándome solo en los datos, elegiría..."

# %%
# Desafío Final — Tu código aquí:

# %% [markdown]
# **Mis conclusiones:**
#
# 1. ...
# 2. ...
# 3. ...
#
# **Mi recomendación de equipo:**
#
# > ...

# %% [markdown]
# ---
# <div style="text-align:center; padding:14px; color:#888; font-size:0.85em;">
# SKILLNEST · Semana 3 Ejercicios · Matplotlib y Visualización de Datos
# </div>
